# %%
import phylopandas as ph
from phylovega import VegaTree

# %% [markdown]
# read in my tree file

# %%
df = ph.read_newick('partition.nxs.treefile')

# %%
df.head()
# Out:
#    distance id label    length parent  type
# 0  0.000000  0     0  0.000000   None  root
# 1  0.230008  1     1  0.230008      0  node
# 2  0.238701  2     2  0.008692      1  node
# 3  0.258683  3     3  0.019982      2  node
# 4  0.264916  4     4  0.006233      3  node

# %% [markdown]
# I want the leaf names to manipulate them

# %%
leaf = df.loc[df['type'] == "leaf"]

# %%
leaf.head()
# Out:
#     distance                         id                      label    length  \
# 8   0.327094     Fragosphaeria purpurea     Fragosphaeria purpurea  0.009175
# 9   0.338654   Fragosphaeria reniformis   Fragosphaeria reniformis  0.020735
# 21  0.384702  Leptographium wingfieldii  Leptographium wingfieldii  0.000825
# 22  0.383879  Leptographium terebrantis  Leptographium terebrantis  0.000002
# 23  0.383074      Ophiostoma clavigerum      Ophiostoma clavigerum  0.000001
#
#    parent  type
# 8       7  leaf
# 9       7  leaf
# 21     18  leaf
# 22     18  leaf
# 23     17  leaf

# %%
vt = VegaTree(df)

# %%
vt.display()
# Out:
# <div class="vega-embed" id="3f19c280-1c16-4e1f-91dd-d82cef15efa5"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
